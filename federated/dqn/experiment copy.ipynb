# %% [markdown]
# FIRST
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.25
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 9e-6
#
# gm = 3e-1
#
# steps = len(xtrain)

# %% [markdown]
# SECOND
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.5
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 9e-6
#
# gm = 3e-1
#
# steps = len(xtrain)

# %% [markdown]
# THIRD
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.05
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 9e-6
#
# gm = 3e-1
#
# steps = len(xtrain)

# %% [markdown]
# FOURTH
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.05
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 9e-6
#
# gm = 1e-1
#
# steps = len(xtrain)

# %% [markdown]
# FIFTH
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.5
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 4e-6
#
# gm = 9e-1
#
# steps = len(xtrain)

# %% [markdown]
# SIXTH
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.05
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 4e-6
#
# gm = 9e-1
#
# steps = len(xtrain)

# %% [markdown]
# SEVENTH
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.05
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 6e-6
#
# gm = 9e-1
#
# steps = len(xtrain)

# %% [markdown]
# EITH 709
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1.05
#
#
# lr = 5e-6
#
# gm = 9e-1
#
# steps = len(xtrain)

# %% [markdown]
# NINETH 810
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1.05
#
#
# lr = 3e-6
#
# gm = 9e-2
#
# steps = len(xtrain)

# %% [markdown]
# TENTH 911
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1.05
#
#
# lr = 3e-6
#
# gm = 9e-1
#
# steps = len(xtrain)

# %% [markdown]
# 1431
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 2e-5
#
# gm = 3e-1
#
# steps = len(xtrain)

# %% [markdown]
# 1633
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 1e-4
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 1734
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 1e-4
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 1835
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
#
# lr = 1e-5
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 1835
#
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
# seed = 50
#
# lr = 1e-5
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 1835
#
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -1.1
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
# seed = 50
#
# lr = 1e-5
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 2161
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -4
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
# seed = 387
#
# lr = 1e-5
#
# gm = 99e-2
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 2361
#
# if (int(action == self.expected_action)):
#
#     reward = 1
#
#     self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#     reward = -4
#
# elif (int(action)==1 and self.expected_action==0):
#
#     reward = -1
#
# seed = 387
#
# lr = 1e-5
#
# gm = 99e-2
#
# exploration_final = 0.15
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 2361 melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 1.1
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -1.5
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -1
#
#
#
#
# seed = 5
#
# lr = 5e-6
#
# gm = 9e-1
#
# steps = 1.1*len(xtrain)

# %% [markdown]
# 2563 melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 1.2
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -2.0
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -1
#
#
#
#
# seed = 5
#
# lr = 8e-6
#
# gm = 9e-1
#
# steps = 1.15*len(xtrain)

# %% [markdown]
# 2856
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 1.2
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -2.0
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -1
#
#
#
#
# seed = 5
#
# lr = 8e-6
#
# gm = 9e-1
#
# steps = 1.15*len(xtrain)

# %% [markdown]
#     2957
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 1.2
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -2.0
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -1
#
#
#
#
# seed = 5
#
# lr = 8e-6
#
# gm = 9e-1
#
# steps = 1.15*len(xtrain)

# %% [markdown]
# 3382
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -1000
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -2
#
#
#
#
# seed = 42
#
# lr = 2e-5
#
# steps = 0.7*len(xtrain)

# %% [markdown]
# 3483
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 10
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -1000
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -2
#
#
#
#
# seed = 42
#
# lr = 5e-5
#
# steps = 0.8*len(xtrain)

# %% [markdown]
# 3584
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 10
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -1000
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -2
#
#
#
#
# seed = 42
#
# lr = 3e-5
#
# steps = 0.7*len(xtrain)

# %% [markdown]
# 3685
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 1
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 10
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -10
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -1
#
#
#
#
# seed = 42
#
# lr = 3e-5
#
# steps = 0.7*len(xtrain)

# %% [markdown]
# 3786
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 3
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 10
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -10
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -3
#
#
#
#
# seed = 42
#
# lr = 3e-5
#
# steps = 0.9*len(xtrain)

# %% [markdown]
# 3887
#
# melhorar o 406
#
#  if (int(action) == 0 and self.expected_action==0):
#
#             reward = 3.3
#
#             self.total_rwd += 1
#
# elif (int(action) == 1 and self.expected_action==1):
#
#             reward = 10
#
#             self.total_rwd += 1
#
# elif (int(action)==0 and self.expected_action==1):
#
#             reward = -10
#
# elif (int(action)==1 and self.expected_action==0):
#
#             reward = -3.3
#
#
#
#
# seed = 42
#
# lr = 3e-5
#
# steps = 0.7*len(xtrain)
